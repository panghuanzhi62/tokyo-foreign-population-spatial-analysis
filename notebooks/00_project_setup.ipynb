# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
import sklearn

print("pandas:", pd.__version__)
print("geopandas:", gpd.__version__)
print("folium:", folium.__version__)
print("scikit-learn imported successfully")
# Out:
# pandas: 3.0.1
# geopandas: 1.1.3
# folium: 0.20.0
# scikit-learn imported successfully

# %%
from pathlib import Path

project_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
print("Project root:", project_root)

folders = ["data_raw", "data_processed", "notebooks", "outputs", "docs", "scripts"]

for folder in folders:
    print(folder, "exists ->", (project_root / folder).exists())
# Out:
# Project root: e:\rsch\laborJapan
# data_raw exists -> True
# data_processed exists -> True
# notebooks exists -> True
# outputs exists -> True
# docs exists -> True
# scripts exists -> True

# %% [markdown]
# # Week 1: Project Setup
#
# ## Goals
# - Set up the project structure
# - Confirm Python environment
# - Prepare research questions and variable framework
# - Build a Japan data source checklist
#
# ## Main study area
# - Tokyo
# - Saitama
# - Chiba
# - Kanagawa
#
# ## Case areas
# - Kawaguchi-shi
# - Edogawa-ku
